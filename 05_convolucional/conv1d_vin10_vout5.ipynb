# %% [markdown]
# # <font color=#0099CC>**CONV1D: V_in = 10, V_out = 5**</font>
#
# ## <font color=#0099CC>**0. INTRODUCCIÓN**</font>
#
# ### <font color=#336699>**0.1. Objetivo de este cuaderno**</font>
#
# Notebook individual para una única combinación del grid 4×4 (**V_in=10**, **V_out=5**). Patrón «1 notebook = 1 combo»: se entrena un modelo **Conv1D** con esa pareja de ventanas y se persiste mediante `BestRunTracker` (callback compartido) la **mejor ejecución histórica** del combo + la última, junto con la curva de entrenamiento. El consolidado de los 16 parciales y los heatmaps los genera `_agregador_conv1d.ipynb`.
#
# Los datos son **log-retornos** multivariantes (23 activos); el MAE se interpreta en esa escala. En esta combinación activamos el escalado `scaler='standard'` (fit **solo** sobre `X_tr`, transform a val/test). La curva incluye como referencia los MAE de los 3 baselines (`buy_and_hold`, `trivial`, `lineal`) para el mismo `(v_in, v_out)`.
#
# **Salidas generadas**:
# - `08_results/runs/conv1d/conv1d_vin10_vout5/best.keras` — pesos+arquitectura de la mejor ejecución histórica
# - `08_results/runs/conv1d/conv1d_vin10_vout5/best.json` — hparams + MAEs + epoch + timestamp del best
# - `08_results/runs/conv1d/conv1d_vin10_vout5/last.json` — última ejecución (auditoría)
# - `08_results/runs/conv1d/conv1d_vin10_vout5/history.csv` — append-only (1 fila por ejecución)
# - `08_results/tablas/parciales/conv1d_vin10_vout5.csv` — escrito desde best.json (mejor histórica)
# - `08_results/curvas/conv1d/conv1d_vin10_vout5.png` — curva con baselines superpuestos

# %% [markdown]
# La partición train/val/test es cronológica con semilla fija (`random_state=42`): **no modificar**. Para otra combinación: duplicar este notebook y cambiar **solo** `V_IN` y `V_OUT` en la sección de configuración.

# %% [markdown]
# ## <font color=#0099CC>**1. ENTORNO DE EJECUCIÓN**</font>
#
# ### <font color=#336699>**1.1. Detección Colab / local y rutas del proyecto**</font>
#
# Se configura `BASE`, el acceso a Drive cuando aplica y el `sys.path` para importar utilidades compartidas sin duplicar código.

# %%
import os, sys

def detect_env():
    try:
        import google.colab
        return 'colab'
    except ImportError:
        return 'local'

ENV = detect_env()

if ENV == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    BASE = '/content/drive/MyDrive/Taller4_DL_MIAX'
else:
    BASE = os.path.abspath(os.path.join(os.getcwd(), '..'))

SRC = os.path.join(BASE, '01_src_compartido')
if SRC not in sys.path:
    sys.path.insert(0, SRC)

print(f'> Entorno : {ENV}')
print(f'> BASE    : {BASE}')
print(f'> SRC     : {SRC}')
# Out:
# > Entorno : local
# > BASE    : /mnt/c/Users/diego/MIAX/11-nn-forecasting-sp/Taller4_DL_MIAX
# > SRC     : /mnt/c/Users/diego/MIAX/11-nn-forecasting-sp/Taller4_DL_MIAX/01_src_compartido

# %% [markdown]
# ## <font color=#0099CC>**2. IMPORTACIONES**</font>
#
# ### <font color=#336699>**2.1. Librerías y módulos compartidos**</font>
#
# Stack numérico, TensorFlow/Keras y utilidades de datos y métricas; se inyecta `BASE` en `metrics_utils` antes de cualquier guardado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from dataset_utils import load_data, create_dataset, get_partitions, TICKERS
import metrics_utils
metrics_utils.BASE_DRIVE = BASE
from metrics_utils import (
    plot_curva,
    BestRunTracker,
    resumen_vs_baselines,
    cargar_best_modelo,
)

print(f'> TensorFlow : {tf.__version__}')
print(f'> GPU        : {tf.config.list_physical_devices("GPU")}')
# Out:
# 2026-05-14 23:41:15.610962: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-14 23:41:15.659917: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-14 23:41:16.336841: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# > TensorFlow : 2.13.0
# > GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-05-14 23:41:17.811147: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:17.849788: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:17.849882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %% [markdown]
# ## <font color=#0099CC>**3. CONFIGURACIÓN DEL EXPERIMENTO**</font>
#
# ### <font color=#336699>**3.1. Combinación de ventanas e hiperparámetros**</font>
#
# Única celda que cambia al duplicar el notebook para otro par **V_in / V_out**.

# %%
MODELO = 'conv1d'
V_IN, V_OUT = 10, 5

EPOCHS     = 1000
BATCH_SIZE = 100
PATIENCE   = 40

SCALER = 'standard'   # None | 'standard' | 'minmax'  — fit SOLO sobre X_tr

print(f'> Combinación: V_in={V_IN}, V_out={V_OUT}')
print(f'> Scaler    : {SCALER}')
# Out:
# > Combinación: V_in=10, V_out=5
# > Scaler    : standard

# %% [markdown]
# ## <font color=#0099CC>**4. DESCARGA DE DATOS**</font>
#
# ### <font color=#336699>**4.1. Serie multivariante y construcción del dataset**</font>
#
# Precios de cierre ajustados de los 23 activos (vía `yfinance`), transformados a log-retornos. Se construyen las ventanas para esta combinación y se particiona cronológicamente (semilla competición = 42). El scaler se ajusta exclusivamente con los datos de entrenamiento y se aplica con `transform` a val/test (sin data-leakage). `Y` se deja sin escalar.

# %%
data, df = load_data()
print(f'> Datos : {data.shape[0]:,} días × {data.shape[1]} activos')
print(f'> Rango : {df.index[0].date()} → {df.index[-1].date()}')

X, Y = create_dataset(data, V_IN, V_OUT)
X_tr, X_val, X_test, Y_tr, Y_val, Y_test, sc = get_partitions(
    X, Y, scaler=SCALER, return_scaler=True, verbose=True, val_size=0.2
)

print(f'> X shape: {X.shape}   Y shape: {Y.shape}')
print(f'> Train: {X_tr.shape[0]:,}  Val: {X_val.shape[0]:,}  Test: {X_test.shape[0]:,}')
if sc is not None:
    print(f'> Scaler: {type(sc).__name__} fitted on X_tr only')
    print(f'>   mean(X_tr_scaled) ≈ {X_tr.mean():+.4f}   std(X_tr_scaled) ≈ {X_tr.std():.4f}')
# Out:
# > Datos : 16,199 días × 23 activos
# > Rango : 1962-01-03 → 2026-05-14
# > Scaler: standard fitted on X_tr only — applied to train/val/test
# > Particiones — Train:  11652  Val:   2914  Test:   1619
# > X shape: (16185, 10, 23)   Y shape: (16185, 23)
# > Train: 11,652  Val: 2,914  Test: 1,619
# > Scaler: StandardScaler fitted on X_tr only
# >   mean(X_tr_scaled) ≈ +0.0000   std(X_tr_scaled) ≈ 1.0000

# %% [markdown]
# ## <font color=#0099CC>**5. MODELO CONV1D**</font>
#
# ### <font color=#336699>**5.2. Arquitectura: Multi-scale (Inception-like)**</font>
#
# Con `V_in=10` interesa capturar patrones a varias escalas temporales (movimientos de 2, 3 y 5 días) sin perder la ventana corta a base de pooling agresivo. Se construye un **bloque Inception-1D**: tres ramas paralelas con `kernel_size` 2, 3 y 5 (padding `same`) más una rama de proyección 1×1; se concatenan a lo largo del eje de filtros. Un segundo bloque idéntico amplía los filtros antes de un `GlobalAveragePooling1D` y un cabezal denso. Loss: `mae`.

# %%
N_ASSETS = len(TICKERS)  # 23

l2 = regularizers.l2(1e-4)

def inception_block(x, filters):
    b1 = layers.Conv1D(filters, 1, padding='same', activation='relu', kernel_regularizer=l2)(x)
    b2 = layers.Conv1D(filters, 2, padding='same', activation='relu', kernel_regularizer=l2)(x)
    b3 = layers.Conv1D(filters, 3, padding='same', activation='relu', kernel_regularizer=l2)(x)
    b5 = layers.Conv1D(filters, 5, padding='same', activation='relu', kernel_regularizer=l2)(x)
    return layers.Concatenate(axis=-1)([b1, b2, b3, b5])

inp = layers.Input(shape=(V_IN, N_ASSETS))

x = inception_block(inp, 32)        # → (10, 128)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.2)(x)

x = inception_block(x, 64)          # → (10, 256)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

x = layers.GlobalAveragePooling1D()(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=l2)(x)
x = layers.Dropout(0.4)(x)
out = layers.Dense(N_ASSETS)(x)

model = models.Model(inp, out)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mae',
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
# 2026-05-14 23:41:30.665720: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:30.665850: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:30.665897: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:30.871513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:30.871608: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:30.871619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-05-14 23:41:30.871658: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-05-14 23:41:30.871692: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
#  input_1 (InputLayer)        [(None, 10, 23)]             0         []
#
#  conv1d (Conv1D)             (None, 10, 32)               768       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 10, 32)               1504      ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 10, 32)               2240      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 10, 32)               3712      ['input_1[0][0]']
#
#  concatenate (Concatenate)   (None, 10, 128)              0         ['conv1d[0][0]',
#                                                                      'conv1d_1[0][0]',
#                                                                      'conv1d_2[0][0]',
#                                                                      'conv1d_3[0][0]']
#
#  batch_normalization (Batch  (None, 10, 128)              512       ['concatenate[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 10, 128)              0         ['batch_normalization[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 10, 64)               8256      ['dropout[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 10, 64)               16448     ['dropout[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 10, 64)               24640     ['dropout[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 10, 64)               41024     ['dropout[0][0]']
#
#  concatenate_1 (Concatenate  (None, 10, 256)              0         ['conv1d_4[0][0]',
#  )                                                                   'conv1d_5[0][0]',
#                                                                      'conv1d_6[0][0]',
#                                                                      'conv1d_7[0][0]']
#
#  batch_normalization_1 (Bat  (None, 10, 256)              1024      ['concatenate_1[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 10, 256)              0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  global_average_pooling1d (  (None, 256)                  0         ['dropout_1[0][0]']
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                   16448     ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout_2 (Dropout)         (None, 64)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 23)                   1495      ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 118071 (461.21 KB)
# Trainable params: 117303 (458.21 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## <font color=#0099CC>**6. ENTRENAMIENTO**</font>
#
# ### <font color=#336699>**6.1. Ajuste con callbacks**</font>
#
# `EarlyStopping` con `restore_best_weights`, `ReduceLROnPlateau` cuando `val_loss` se estanca y `BestRunTracker`, que durante el fit guarda en `best.keras` la mejor época y al terminar:
# - escribe siempre `last.json` (última ejecución),
# - si la `mae_val` mejora la histórica del combo, pisa `best.json` y el CSV parcial,
# - añade una fila a `history.csv` (append-only).
#
# Si la nueva ejecución no mejora, el `best.keras` previo se restaura intacto.

# %%
es = EarlyStopping(
    monitor='val_loss', patience=PATIENCE,
    restore_best_weights=True, verbose=1,
)

rlr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=15,
    min_lr=1e-6, verbose=1,
)

tracker = BestRunTracker(
    MODELO, V_IN, V_OUT,
    datasets=(X_tr, Y_tr, X_val, Y_val, X_test, Y_test), auto_plot=True,
    hparams_extra={
        'batch_size': BATCH_SIZE,
        'patience':   PATIENCE,
        'epochs_max': EPOCHS,
        'scaler':     SCALER,
    },
)

history = model.fit(
    X_tr, Y_tr,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[es, rlr, tracker],
    verbose=2,
)

print(f'> Epochs entrenadas: {len(history.history["loss"])}')
print(f'> Best val_loss   : {min(history.history["val_loss"]):.5f}')

# %% [markdown]
# ## <font color=#0099CC>**7. MÉTRICAS Y PERSISTENCIA**</font>
#
# ### <font color=#336699>**7.1. MAE por partición y comparativa con baselines**</font>
#
# `BestRunTracker` ya ha persistido el `best.keras`, `best.json`, `last.json`, `history.csv` y el CSV parcial (este último siempre con la mejor histórica). Aquí solo:
# - dibujamos la curva de entrenamiento con líneas horizontales de los 3 baselines como referencia,
# - imprimimos la comparativa MAE modelo-vs-baselines del combo.
#
# `_agregador_conv1d.ipynb` consolidará los 16 parciales en `conv1d_resultados.csv` y generará los heatmaps.

# %%
maes = tracker.maes_last  # MAE train/val/test del best.keras de esta ejecución

plot_curva(history, MODELO, V_IN, V_OUT, mostrar_baselines=True, save=tracker.improved)
plt.show()

resumen_vs_baselines(maes, V_IN, V_OUT, nombre_modelo=MODELO, verbose=True, n_params=model.count_params())


print(f'\n> MAE  train={maes["train"]:.4f}  val={maes["val"]:.4f}  test={maes["test"]:.4f}'
      f'  params={model.count_params():,}')
print(f'> Artefactos en: 08_results/runs/{MODELO}/{MODELO}_vin{V_IN}_vout{V_OUT}/')
# Out:
# > Comparativa MAE — V_in=10, V_out=5
# <style type="text/css">
# </style>
# <table id="T_b9df3">
#   <thead>
#     <tr>
#       <th id="T_b9df3_level0_col0" class="col_heading level0 col0" >baseline</th>
#       <th id="T_b9df3_level0_col1" class="col_heading level0 col1" >n_params</th>
#       <th id="T_b9df3_level0_col2" class="col_heading level0 col2" >mae_train</th>
#       <th id="T_b9df3_level0_col3" class="col_heading level0 col3" >mae_val</th>
#       <th id="T_b9df3_level0_col4" class="col_heading level0 col4" >mae_test</th>
#       <th id="T_b9df3_level0_col5" class="col_heading level0 col5" >mejora_test_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b9df3_row0_col0" class="data row0 col0" >conv1d</td>
#       <td id="T_b9df3_row0_col1" class="data row0 col1" >118,071</td>
#       <td id="T_b9df3_row0_col2" class="data row0 col2" >0.00537</td>
#       <td id="T_b9df3_row0_col3" class="data row0 col3" >0.00537</td>
#       <td id="T_b9df3_row0_col4" class="data row0 col4" >0.00529</td>
#       <td id="T_b9df3_row0_col5" class="data row0 col5" >—</td>
#     </tr>
#     <tr>
#       <td id="T_b9df3_row1_col0" class="data row1 col0" >buy_and_hold</td>
#       <td id="T_b9df3_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_b9df3_row1_col2" class="data row1 col2" >0.00548</td>
#       <td id="T_b9df3_row1_col3" class="data row1 col3" >0.00416</td>
#       <td id="T_b9df3_row1_col4" class="data row1 col4" >0.00562</td>
#       <td id="T_b9df3_row1_col5" class="data row1 col5" >+5.75%</td>
#     </tr>
#     <tr>
#       <td id="T_b9df3_row2_col0" class="data row2 col0" >trivial</td>
#       <td id="T_b9df3_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_b9df3_row2_col2" class="data row2 col2" >0.00686</td>
#       <td id="T_b9df3_row2_col3" class="data row2 col3" >0.00528</td>
#       <td id="T_b9df3_row2_col4" class="data row2 col4" >0.00693</td>
#       <td id="T_b9df3_row2_col5" class="data row2 col5" >+23.55%</td>
#     </tr>
#     <tr>
#       <td id="T_b9df3_row3_col0" class="data row3 col0" >lineal</td>
#       <td id="T_b9df3_row3_col1" class="data row3 col1" >5,313</td>
#       <td id="T_b9df3_row3_col2" class="data row3 col2" >0.00542</td>
#       <td id="T_b9df3_row3_col3" class="data row3 col3" >0.00421</td>
#       <td id="T_b9df3_row3_col4" class="data row3 col4" >0.00572</td>
#       <td id="T_b9df3_row3_col5" class="data row3 col5" >+7.39%</td>
#     </tr>
#   </tbody>
# </table>
# > MAE  train=0.0054  val=0.0054  test=0.0053  params=118,071
# > Artefactos en: 08_results/runs/conv1d/conv1d_vin10_vout5/

# %% [markdown]
# ## <font color=#0099CC>**8. CONSOLIDACIÓN 4×4**</font>
#
# ### <font color=#336699>**8.1. Heatmaps y tabla global**</font>
#
# Los mapas de calor MAE y la tabla completa del modelo **Conv1D** sobre todas las combinaciones no se generan aquí; ejecutar `_agregador_conv1d.ipynb` cuando existan los 16 CSV parciales.
