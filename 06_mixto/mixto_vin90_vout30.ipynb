# %% [markdown]
# # <font color=#0099CC>**MIXTO (Conv1D + RNN): V_in = 90, V_out = 30**</font>
#
# ## <font color=#0099CC>**0. INTRODUCCIÓN**</font>
#
# ### <font color=#336699>**0.1. Objetivo de este cuaderno**</font>
#
# Notebook individual para una única combinación del grid 4×4 (**V_in=90**, **V_out=30**). Patrón «1 notebook = 1 combo»: se entrena un modelo **Mixto (Conv1D + RNN)** con esa pareja de ventanas y se persiste mediante `BestRunTracker` (callback compartido) la **mejor ejecución histórica** del combo + la última, junto con la curva de entrenamiento. El consolidado de los 16 parciales y los heatmaps los genera `_agregador_mixto.ipynb`.
#
# Los datos son **log-retornos** multivariantes (23 activos); el MAE se interpreta en esa escala. En esta combinación activamos el escalado `scaler='standard'` (fit **solo** sobre `X_tr`, transform a val/test). La curva incluye como referencia los MAE de los 3 baselines (`buy_and_hold`, `trivial`, `lineal`) para el mismo `(v_in, v_out)`.
#
# **Salidas generadas**:
# - `08_results/runs/mixto/mixto_vin90_vout30/best.keras` — pesos+arquitectura de la mejor ejecución histórica
# - `08_results/runs/mixto/mixto_vin90_vout30/best.json` — hparams + MAEs + epoch + timestamp del best
# - `08_results/runs/mixto/mixto_vin90_vout30/last.json` — última ejecución (auditoría)
# - `08_results/runs/mixto/mixto_vin90_vout30/history.csv` — append-only (1 fila por ejecución)
# - `08_results/tablas/parciales/mixto_vin90_vout30.csv` — escrito desde best.json (mejor histórica)
# - `08_results/curvas/mixto/mixto_vin90_vout30.png` — curva con baselines superpuestos

# %% [markdown]
# La partición train/val/test es cronológica con semilla fija (`random_state=42`): **no modificar**. Para otra combinación: duplicar este notebook y cambiar **solo** `V_IN` y `V_OUT` en la sección de configuración.

# %% [markdown]
# ## <font color=#0099CC>**1. ENTORNO DE EJECUCIÓN**</font>
#
# ### <font color=#336699>**1.1. Detección Colab / local y rutas del proyecto**</font>
#
# Se configura `BASE`, el acceso a Drive cuando aplica y el `sys.path` para importar utilidades compartidas sin duplicar código.

# %%
import os, sys

def detect_env():
    try:
        import google.colab
        return 'colab'
    except ImportError:
        return 'local'

ENV = detect_env()

if ENV == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    BASE = '/content/drive/MyDrive/Taller4_DL_MIAX'
else:
    BASE = os.path.abspath(os.path.join(os.getcwd(), '..'))

SRC = os.path.join(BASE, '01_src_compartido')
if SRC not in sys.path:
    sys.path.insert(0, SRC)

print(f'> Entorno : {ENV}')
print(f'> BASE    : {BASE}')
print(f'> SRC     : {SRC}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# > Entorno : colab
# > BASE    : /content/drive/MyDrive/Taller4_DL_MIAX
# > SRC     : /content/drive/MyDrive/Taller4_DL_MIAX/01_src_compartido

# %% [markdown]
# ## <font color=#0099CC>**2. IMPORTACIONES**</font>
#
# ### <font color=#336699>**2.1. Librerías y módulos compartidos**</font>
#
# Stack numérico, TensorFlow/Keras y utilidades de datos y métricas; se inyecta `BASE` en `metrics_utils` antes de cualquier guardado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from dataset_utils import load_data, create_dataset, get_partitions, TICKERS
import metrics_utils
metrics_utils.BASE_DRIVE = BASE
from metrics_utils import (
    plot_curva,
    BestRunTracker,
    resumen_vs_baselines,
    cargar_best_modelo,
)

print(f'> TensorFlow : {tf.__version__}')
print(f'> GPU        : {tf.config.list_physical_devices("GPU")}')
# Out:
# > TensorFlow : 2.20.0
# > GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## <font color=#0099CC>**3. CONFIGURACIÓN DEL EXPERIMENTO**</font>
#
# ### <font color=#336699>**3.1. Combinación de ventanas e hiperparámetros**</font>
#
# Única celda que cambia al duplicar el notebook para otro par **V_in / V_out**.

# %%
MODELO = 'mixto'
V_IN, V_OUT = 90, 30

EPOCHS     = 5000
BATCH_SIZE = 32
PATIENCE   = 500

SCALER = 'standard'   # None | 'standard' | 'minmax'  — fit SOLO sobre X_tr

print(f'> Combinación: V_in={V_IN}, V_out={V_OUT}')
print(f'> Scaler    : {SCALER}')
# Out:
# > Combinación: V_in=90, V_out=30
# > Scaler    : standard

# %% [markdown]
# ## <font color=#0099CC>**4. DESCARGA DE DATOS**</font>
#
# ### <font color=#336699>**4.1. Serie multivariante y construcción del dataset**</font>
#
# Precios de cierre ajustados de los 23 activos (vía `yfinance`), transformados a log-retornos. Se construyen las ventanas para esta combinación y se particiona cronológicamente (semilla competición = 42). El scaler se ajusta exclusivamente con los datos de entrenamiento y se aplica con `transform` a val/test (sin data-leakage). `Y` se deja sin escalar.

# %%
data, df = load_data()
print(f'> Datos : {data.shape[0]:,} días × {data.shape[1]} activos')
print(f'> Rango : {df.index[0].date()} → {df.index[-1].date()}')

X, Y = create_dataset(data, V_IN, V_OUT)
X_tr, X_val, X_test, Y_tr, Y_val, Y_test, sc = get_partitions(
    X, Y, scaler=SCALER, return_scaler=True, verbose=True, val_size= 0.2
)

print(f'> X shape: {X.shape}   Y shape: {Y.shape}')
print(f'> Train: {X_tr.shape[0]:,}  Val: {X_val.shape[0]:,}  Test: {X_test.shape[0]:,}')
if sc is not None:
    print(f'> Scaler: {type(sc).__name__} fitted on X_tr only')
    print(f'>   mean(X_tr_scaled) ≈ {X_tr.mean():+.4f}   std(X_tr_scaled) ≈ {X_tr.std():.4f}')
# Out:
# > Datos : 16,201 días × 23 activos
# > Rango : 1962-01-03 → 2026-05-18
# > Scaler: standard fitted on X_tr only — applied to train/val/test
# > Particiones — Train:  11578  Val:   2895  Test:   1609
# > X shape: (16082, 90, 23)   Y shape: (16082, 23)
# > Train: 11,578  Val: 2,895  Test: 1,609
# > Scaler: StandardScaler fitted on X_tr only
# >   mean(X_tr_scaled) ≈ -0.0000   std(X_tr_scaled) ≈ 1.0000

# %% [markdown]
# ## <font color=#0099CC>**5. MODELO MIXTO (Conv1D + RNN)**</font>
#
# ### <font color=#336699>**5.1. Arquitectura y compilación**</font>
#
# Tres bloques Conv1D con **strides** (downsampling aprendido en lugar de pooling): `Conv1D(48, k=7, strides=2)` (90→45), `Conv1D(72, k=5, strides=2)` (45→23) y `Conv1D(96, k=3, strides=1)`, todos con padding `same`, relu, L2 y `BatchNormalization` + `Dropout(0.2/0.2/0.25)`. A continuación un **`Bidirectional(LSTM(48))`** con `BatchNormalization` + `Dropout(0.3)` y cabezal denso de dos capas (80 → 40 unidades, relu + Dropout 0.35/0.3). Loss: `mae`.
#
# **Justificación del cambio (vs. arquitectura previa 2×(Conv+MaxPool)+GRU):** reemplazamos **MaxPooling por convoluciones con stride 2**, que son una forma **aprendible** de submuestrear (en vez de tomar el máximo determinista). La pirámide Conv (48→72→96 filtros, strides 2→2→1) comprime la entrada de 90 pasos a una secuencia de 23 pasos con rasgos progresivamente más ricos. Sobre esa representación comprimida usamos un **LSTM bidireccional**: en el cuello de botella ya podemos permitírnoslo en términos de cómputo, y la bidireccionalidad le permite al modelo usar información 'futura dentro de ventana' a nivel de rasgos abstractos. Total ~115k parámetros (vs. ~133k del original).

# %%
N_ASSETS = len(TICKERS)  # 23

l2 = regularizers.l2(1e-4)

model = models.Sequential([
    layers.Conv1D(
        filters=48,
        kernel_size=7,
        strides=2,
        padding='same',
        activation='relu',
        input_shape=(V_IN, N_ASSETS),
        kernel_regularizer=l2,
    ),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Conv1D(
        filters=72,
        kernel_size=5,
        strides=2,
        padding='same',
        activation='relu',
        kernel_regularizer=l2,
    ),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Conv1D(
        filters=96,
        kernel_size=3,
        padding='same',
        activation='relu',
        kernel_regularizer=l2,
    ),
    layers.BatchNormalization(),
    layers.Dropout(0.25),

    layers.Bidirectional(
        layers.LSTM(48, return_sequences=False, kernel_regularizer=l2)
    ),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(80, activation='relu', kernel_regularizer=l2),
    layers.Dropout(0.35),
    layers.Dense(40, activation='relu', kernel_regularizer=l2),
    layers.Dropout(0.3),

    layers.Dense(N_ASSETS),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='mae',
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 45, 48)         │         7,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 45, 48)         │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 45, 48)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 23, 72)         │        17,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 23, 72)         │           288 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 23, 72)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 23, 96)         │        20,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 23, 96)         │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 23, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 96)             │        55,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 96)             │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 80)             │         7,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 40)             │         3,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 40)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 23)             │           943 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,831 (448.56 KB)
#  Trainable params: 114,207 (446.12 KB)
#  Non-trainable params: 624 (2.44 KB)

# %% [markdown]
# ## <font color=#0099CC>**6. ENTRENAMIENTO**</font>
#
# ### <font color=#336699>**6.1. Ajuste con callbacks**</font>
#
# `EarlyStopping` con `restore_best_weights`, `ReduceLROnPlateau` cuando `val_loss` se estanca y `BestRunTracker`, que durante el fit guarda en `best.keras` la mejor época y al terminar:
# - escribe siempre `last.json` (última ejecución),
# - si la `mae_val` mejora la histórica del combo, pisa `best.json` y el CSV parcial,
# - añade una fila a `history.csv` (append-only).
#
# Si la nueva ejecución no mejora, el `best.keras` previo se restaura intacto.

# %%
es = EarlyStopping(
    monitor='val_loss', patience=PATIENCE,
    restore_best_weights=True, verbose=1,
)

rlr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.8, patience=20,
    min_lr=1e-6, verbose=1,
)

tracker = BestRunTracker(
    MODELO, V_IN, V_OUT,
    datasets=(X_tr, Y_tr, X_val, Y_val, X_test, Y_test), auto_plot=True,
    hparams_extra={
        'batch_size': BATCH_SIZE,
        'patience':   PATIENCE,
        'epochs_max': EPOCHS,
        'scaler':     SCALER,
    },
)

history = model.fit(
    X_tr, Y_tr,
    validation_data=(X_val, Y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[es, rlr, tracker],
    verbose=2,
)

print(f'> Epochs entrenadas: {len(history.history["loss"])}')
print(f'> Best val_loss   : {min(history.history["val_loss"]):.5f}')

# %% [markdown]
# ## <font color=#0099CC>**7. MÉTRICAS Y PERSISTENCIA**</font>
#
# ### <font color=#336699>**7.1. MAE por partición y comparativa con baselines**</font>
#
# `BestRunTracker` ya ha persistido el `best.keras`, `best.json`, `last.json`, `history.csv` y el CSV parcial (este último siempre con la mejor histórica). Aquí solo:
# - dibujamos la curva de entrenamiento con líneas horizontales de los 3 baselines como referencia,
# - imprimimos la comparativa MAE modelo-vs-baselines del combo.
#
# `_agregador_mixto.ipynb` consolidará los 16 parciales en `mixto_resultados.csv` y generará los heatmaps.

# %%
maes = tracker.maes_last  # MAE train/val/test del best.keras de esta ejecución

plot_curva(history, MODELO, V_IN, V_OUT, mostrar_baselines=True, save=tracker.improved)
plt.show()

resumen_vs_baselines(maes, V_IN, V_OUT, nombre_modelo=MODELO)

print(f'\n> MAE  train={maes["train"]:.4f}  val={maes["val"]:.4f}  test={maes["test"]:.4f}'
      f'  params={model.count_params():,}')
print(f'> Artefactos en: 08_results/runs/{MODELO}/{MODELO}_vin{V_IN}_vout{V_OUT}/')
# Out:
# > Comparativa MAE — V_in=90, V_out=30
# <style type="text/css">
# </style>
# <table id="T_7605a" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_7605a_level0_col0" class="col_heading level0 col0" >baseline</th>
#       <th id="T_7605a_level0_col1" class="col_heading level0 col1" >n_params</th>
#       <th id="T_7605a_level0_col2" class="col_heading level0 col2" >mae_train</th>
#       <th id="T_7605a_level0_col3" class="col_heading level0 col3" >mae_val</th>
#       <th id="T_7605a_level0_col4" class="col_heading level0 col4" >mae_test</th>
#       <th id="T_7605a_level0_col5" class="col_heading level0 col5" >mejora_test_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7605a_row0_col0" class="data row0 col0" >mixto</td>
#       <td id="T_7605a_row0_col1" class="data row0 col1" >—</td>
#       <td id="T_7605a_row0_col2" class="data row0 col2" >0.00220</td>
#       <td id="T_7605a_row0_col3" class="data row0 col3" >0.00194</td>
#       <td id="T_7605a_row0_col4" class="data row0 col4" >0.00233</td>
#       <td id="T_7605a_row0_col5" class="data row0 col5" >—</td>
#     </tr>
#     <tr>
#       <td id="T_7605a_row1_col0" class="data row1 col0" >buy_and_hold</td>
#       <td id="T_7605a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_7605a_row1_col2" class="data row1 col2" >0.00224</td>
#       <td id="T_7605a_row1_col3" class="data row1 col3" >0.00175</td>
#       <td id="T_7605a_row1_col4" class="data row1 col4" >0.00236</td>
#       <td id="T_7605a_row1_col5" class="data row1 col5" >+1.44%</td>
#     </tr>
#     <tr>
#       <td id="T_7605a_row2_col0" class="data row2 col0" >trivial</td>
#       <td id="T_7605a_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7605a_row2_col2" class="data row2 col2" >0.00254</td>
#       <td id="T_7605a_row2_col3" class="data row2 col3" >0.00196</td>
#       <td id="T_7605a_row2_col4" class="data row2 col4" >0.00276</td>
#       <td id="T_7605a_row2_col5" class="data row2 col5" >+15.79%</td>
#     </tr>
#     <tr>
#       <td id="T_7605a_row3_col0" class="data row3 col0" >lineal</td>
#       <td id="T_7605a_row3_col1" class="data row3 col1" >47,633</td>
#       <td id="T_7605a_row3_col2" class="data row3 col2" >0.00203</td>
#       <td id="T_7605a_row3_col3" class="data row3 col3" >0.00188</td>
#       <td id="T_7605a_row3_col4" class="data row3 col4" >0.00263</td>
#       <td id="T_7605a_row3_col5" class="data row3 col5" >+11.63%</td>
#     </tr>
#   </tbody>
# </table>
# > MAE  train=0.0022  val=0.0019  test=0.0023  params=114,831
# > Artefactos en: 08_results/runs/mixto/mixto_vin90_vout30/

# %% [markdown]
# ## <font color=#0099CC>**8. CONSOLIDACIÓN 4×4**</font>
#
# ### <font color=#336699>**8.1. Heatmaps y tabla global**</font>
#
# Los mapas de calor MAE y la tabla completa del modelo **Mixto** sobre todas las combinaciones no se generan aquí; ejecutar `_agregador_mixto.ipynb` cuando existan los 16 CSV parciales.
